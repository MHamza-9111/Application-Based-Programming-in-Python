# %% [markdown]
# # Session 1 : Intro to Jupyter Notebook & Python

# %%
print("My name is Hamza Mughal")
# Out:
# My name is Hamza Mughal

# %%
print(6512)
# Out:
# 6512

# %%
print(6 + 2)
# Out:
# 8

# %%
print(6 > 10)
# Out:
# False

# %%
print(6 < 10)
# Out:
# True
